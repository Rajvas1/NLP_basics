# %%
# Functions
def hi():
    print('i am rajashekhar')
hi()
# Out:
# i am rajashekhar

# %%
# Functions with Parameters

def hello_person(name):         #parameters
    print(f" hello, {name}")

# %%
hello_person("rajshekhar")
hello_person("windows")
# Out:
#  hello, rajshekhar
#  hello, windows

# %%
def multi_parameters(name,desig): # # parameters
    print(f' iam {name} , and i am working as {desig}')

# %%
multi_parameters("rajashekhar" , "software") # # Arguments
# Out:
#  iam rajashekhar , and i am working as software

# %%
def multi_parameters(fruits,function):
    print(f" this is {fruits} and it is very{function}")

# %%
multi_parameters("banana" , "healthy")
# Out:
#  this is banana and it is veryhealthy

# %%
def multi_parameters(doing, what):
    print(f" i am learning {doing}, and it is helping me to {what}")

# %%
multi_parameters("Generative AI", "to get a Job")
# Out:
#  i am learning Generative AI, and it is helping me to to get a Job

# %%
def claculate_rect(length, width, unit):
  """Calculate rectangle area"""

  area = length * width   #keep trying this , i am not able to do it
  print(f" Rectangle: {length}{unit} X {width}{unit}")
  print(f" Area: {area} square {unit}")

# %%
claculate_rect(5,3, "cm")
# Out:
#  Rectangle: 5cm X 3cm
#  Area: 15 square cm

# %%
# Return statement
def num_sum(x,b):
    print(f" sum: {x+b}")

# %%
num_sum(2,4)
# Out:
#  sum: 6

# %%
def num_sum(x,y):
    return x+y

# %%
num_sum(20,30)
# Out:
# 50

# %%
def num_mul(a,b):
    return a*b

# %%
num_mul(2,6)
# Out:
# 12

# %%
def num_division (a,b):
    return a/b

# %%
num_division (20,2)
# Out:
# 10.0

# %%
def calculate (a,b):
    sum_result = a+b
    dif_result = a-b
    prod_result = a*b

    return sum_result, dif_result, prod_result

# %%
calculate(30,10)
# Out:
# (40, 20, 300)

# %%
def check_positive(num):
    if num<=0:
        return "negative"
    return "positive"

# %%
check_positive(10)
# Out:
# 'positive'

# %%
check_positive(-10)
# Out:
# 'negative'
