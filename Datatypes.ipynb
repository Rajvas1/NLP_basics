# %%
for  i in range(1,11):
 for j in range(1,11):
        if i == 8:
            print(f"(i) * (j) = (i*j)")
# Out:
# (i) * (j) = (i*j)
# (i) * (j) = (i*j)
# (i) * (j) = (i*j)
# (i) * (j) = (i*j)
# (i) * (j) = (i*j)
# (i) * (j) = (i*j)
# (i) * (j) = (i*j)
# (i) * (j) = (i*j)
# (i) * (j) = (i*j)
# (i) * (j) = (i*j)

# %%
import re
import nltk
from nltk.tokenize import word_tokenize


from textblob import TextBlob


incorrect_text = "Wee arre havaing nlp clllass morring 9 and larning the texts prrrproceessing"

TextBlb = TextBlob(incorrect_text)

TextBlb.correct().string

# Data types
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 6
#       2 import nltk
#       3 from nltk.tokenize import word_tokenize
# ----> 6 from textblob import TextBlob
#       9 incorrect_text = "Wee arre havaing nlp clllass morring 9 and larning the texts prrrproceessing"
#      11 TextBlb = TextBlob(incorrect_text)
#
# ModuleNotFoundError: No module named 'textblob'

# %%
x = 25
year = 2025
neg_number = -9
x
year
neg_number
x
year
# Out:
# 2025

# %%
# arithmatic operators - addition, substractions, multiplications, division,modulus (%), exponents (2**2 , 2 to the power 4), floor division (//)
# # Operators (addition)
a = 10
b = 20
a+b
# Out:
# 30

# %%
# Operators (substraction)
a = 30
b = 20
a-b
# Out:
# 10

# %%
#operators (multiplication)
a = 30
b = 3
a*b
# Out:
# 90

# %%
#operators (division)
a = 10
b = 20
a*b
# Out:
# 200

# %%
# operators (modulus %) it will give the remainder value
a = 5
b = 2
a%b
# Out:
# 1

# %%
# operators exponents (it will give like 2 to the power 3 = 2*2*2 = 8)
a = 2
b = 3
a**3
# Out:
# 8

# %%
# operators floor division (// after intigers it will remove the decimals and give the integer only)
a = 21  #
b = 2
a//b # here if we divide 21 with 2 we will get 10.5 but floor division give integer value only
# Out:
# 10

# %%
# float
a = 15
b = 2
a/b
# Out:
# 7.5

# %%
# float
a = 15.4
b = 2.4
a+b
# Out:
# 17.8

# %%
# Strings
name = 'rajashekhar'
city = "hyderabad"
huge_txt = """
hi this is string class and learning strings methods too!
"""
name
# Out:
# 'rajashekhar'

# %%
huge_txt
# Out:
# '\nhi this is string class and learning strings methods too!\n'

# %%
len(name)
# Out:
# 11

# %%
type(name)
# Out:
# str

# %%
name.upper()
# Out:
# 'RAJASHEKHAR'

# %%
x = 'PYTHON'
x.lower()
# Out:
# 'python'

# %%
type(x)
# Out:
# str

# %%
name = 'PHYTHON'
name.upper()
# Out:
# 'PHYTHON'

# %%
# In string we have two important mechanisms 
#1.indexing – we can fetch single letter in string with indexing number
#2.slicing – we can fetch multiple character in string with indexing number

str = "rajashekhar" #here 0 to 11 characters, this is indexing
# Out:
# 'r'

# %%
str[5] #index
# Out:
# 'h'

# %%
str[9] #index
# Out:
# 'a'

# %%
str[-1] #index
# Out:
# 'r'

# %%
str[-10] #index
# Out:
# 'a'

# %%
str[0::2] #slicing
# Out:
# 'rjsehr'

# %%
str[0:11] #slicing
# Out:
# 'rajashekhar'

# %%
# String Methods
str_meth = "genAI is fantastic"
str_meth.capitalize()
# Out:
# 'Genai is fantastic'

# %%
str_meth.title()
# Out:
# 'Genai Is Fantastic'

# %%
str_meth.replace('fantastic' , 'great')
# Out:
# 'genAI is great'

# %%
str_meth.replace('genAI' , 'gunAI')
# Out:
# 'gunAI is fantastic'

# %%
str_meth
# Out:
# 'genAI is fantastic'

# %%
str_meth.split()
# Out:
# ['genAI', 'is', 'fantastic']

# %%
f_name =  'Rajashekhar'
s_name = 'Vasala'
f_names = f_name + '_' + s_name
f_names
# Out:
# 'Rajashekhar_Vasala'

# %%
str = "rajashekhar"
str.replace("rajashekhar" , "shekhar")
# Out:
# 'shekhar'

# %%
#Join()

join_str = ("gen" , "Ai" , "fantastic")
join_str
# Out:
# ('gen', 'Ai', 'fantastic')

# %%
j_str = ' '.join(join_str)
j_str
# Out:
# 'gen Ai fantastic'

# %%
file_name = 'raja.pdf'
email = 'raja@gmail.com'
file_name.startswith('pdf')
# Out:
# False

# %%
#startswith() and endswith(
file_name.startswith('raja')
# Out:
# True

# %%
file_name.endswith('gmail')
# Out:
# False

# %%
'@' in email
# Out:
# True

# %%
#isdigit() isalpha()
name = "rajashekhar"
name.isdigit()
# Out:
# False

# %%
name.isalpha()
# Out:
# True

# %%
nums = '23456'
nums.isalnum()
# Out:
# True

# %%
nums.isidentifier()
# Out:
# False

# %%
nums.isalnum()
# Out:
# True

# %%
#trimming and removing
review = "  this is very interested.  "
review.strip()
# Out:
# 'this is very interested.'

# %%
review.lstrip()
# Out:
# 'this is very interested.  '

# %%
review.rstrip()
# Out:
# '  this is very interested.'

# %%
#BOOLEANS True or False
is_class = True
is_class
# Out:
# True

# %%
10>3
# Out:
# True

# %%
10<2
# Out:
# False

# %%
10 != 2
# Out:
# True

# %%
10 != 10
# Out:
# False

# %%
#LISTS - to add a single element to the end of that list
lang = ["c","c++","java","python"]
lang.append("javascrip")
lang
# Out:
# ['c', 'c++', 'java', 'python', 'javascrip']

# %%
type(lang)
# Out:
# list

# %%
nums = [2,3,4,5,6]
nums.insert(1,70) # here we have inserted 70 num after 1st place
nums
# Out:
# [2, 70, 3, 4, 5, 6]

# %%
x = ['apple' , 'kiwi' , 'banana']
fruits = ['orange' , 'blueberries']
fruits.extend(x)
fruits
# Out:
# ['orange', 'blueberries', 'apple', 'kiwi', 'banana']

# %%
fruits = ['apple' , 'banana' , 'kiwi']
fruits.remove('banana')
fruits
# Out:
# ['apple', 'kiwi']

# %%
#pop Removes and returns the last item in the list
nums = [20,30,40,50,60,70,80]
nums.pop()
# Out:
# 80

# %%
temp = [1,2,3,4,5,6]
temp.clear()
temp
# Out:
# []

# %%
temp = [2,3,4,5,6,7,8]
del temp[4]
temp
# Out:
# [2, 3, 4, 5, 7, 8]

# %%
mixed_list = ['rajshekhar','ture',["taking",'phython'],{'rajashekhar':'DS'}]
mixed_list
# Out:
# ['rajshekhar', 'ture', ['taking', 'phython'], {'rajashekhar': 'DS'}]

# %%
mixed_list[-1]
# Out:
# {'rajashekhar': 'DS'}

# %%
mixed_list[0]
# Out:
# 'rajshekhar'

# %%
mixed_list[2]
# Out:
# ['taking', 'phython']

# %%
mixed_list[0:2]
# Out:
# ['rajshekhar', 'ture']

# %%
mixed_list[0::2]
# Out:
# ['rajshekhar', ['taking', 'phython']]

# %%
# Functions
def hi():
    print('i am rajashekhar')
hi()
# Out:
# i am rajashekhar

# %%
# Functions with Parameters

def hello_person(name):         #parameters
    print(f" hello, {name}")

# %%
hello_person("rajashekhar")
hello_person("windows")
# Out:
#  hello, rajashekhar
#  hello, windows

# %%
def multi_parameters(name,desig): # # parameters
    print(f' iam {name} , and i am working as {desig}')

# %%
multi_parameters("rajashekhar" , "software") # # Arguments
# Out:
#  iam rajashekhar , and i am working as software

# %%
def multi_parameters(fruits,function):
    print(f" this is {fruits} and it is very{function}")

# %%
multi_parameters("banana" , "healthy")
# Out:
#  this is banana and it is veryhealthy

# %%
def multi_parameters(doing, what):
    print(f" i am learning {doing}, and it is helping me to {what}")

# %%
multi_parameters("Generative AI", "to get a Job")
# Out:
#  i am learning Generative AI, and it is helping me to to get a Job
